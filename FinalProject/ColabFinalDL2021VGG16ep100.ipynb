# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.layers import LeakyReLU
from keras.optimizers import Adam
import cv2
import keras
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
age_data = pd.read_csv('gdrive/My Drive/age_gender.csv')

# %%
age_data.head(3)
# Out:
#    age  ...                                             pixels
# 0    1  ...  129 128 128 126 127 130 133 135 139 142 145 14...
# 1    1  ...  164 74 111 168 169 171 175 182 184 188 193 199...
# 2    1  ...  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
#
# [3 rows x 5 columns]

# %%
def label_age (row):
    if row['age'] > 0 and row['age'] < 8:
        return 0
    elif row['age'] > 7 and row['age'] < 16:
        return 1
    elif row['age'] > 15 and row['age'] < 26:
        return 2
    elif row['age'] > 25 and row['age'] < 36:
        return 3
    elif row['age'] > 35 and row['age'] < 46:
        return 4
    elif row['age'] > 45 and row['age'] < 66:
        return 5
    else:
        return 6

# %%
age_data['AgeGroup'] = age_data.apply (lambda row: label_age(row), axis=1)

# %%
age_data.head(3)
# Out:
#    age  ethnicity  ...                                             pixels AgeGroup
# 0    1          2  ...  129 128 128 126 127 130 133 135 139 142 145 14...        0
# 1    1          2  ...  164 74 111 168 169 171 175 182 184 188 193 199...        0
# 2    1          2  ...  67 70 71 70 69 67 70 79 90 103 116 132 145 155...        0
#
# [3 rows x 6 columns]

# %%
X = []
y = []
for index, row in age_data.iterrows():
    k = row['pixels'].split(" ")
    X.append(np.array(k))
    y.append(row['AgeGroup'])
        
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.9, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.8/0.9, random_state=42)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_valid = np.array(X_valid)
y_valid = np.array(y_valid)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train.reshape(X_train.shape[0], 48, 48, 1)
X_valid = X_valid.reshape(X_valid.shape[0], 48, 48, 1)
X_test = X_test.reshape(X_test.shape[0], 48, 48, 1)

y_train = np_utils.to_categorical(y_train, num_classes = 7)
y_valid = np_utils.to_categorical(y_valid, num_classes = 7)
y_test = np_utils.to_categorical(y_test, num_classes = 7)

# %%
X_train.shape
# Out:
# (18963, 48, 48, 1)

# %%
X_valid.shape
# Out:
# (2371, 48, 48, 1)

# %%
X_test.shape
# Out:
# (2371, 48, 48, 1)

# %%
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(48,48,1)))
model.add(Convolution2D(64, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer= 'sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train,y_train,batch_size=32,epochs=100,verbose=1,validation_data=(X_valid, y_valid))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 18963 samples, validate on 2371 samples
# Epoch 1/100
# 18963/18963 [==============================] - 48s 3ms/step - loss: 1.7896 - accuracy: 0.3198 - val_loss: 1.6709 - val_accuracy: 0.3859
# Epoch 2/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 1.5445 - accuracy: 0.3996 - val_loss: 1.4280 - val_accuracy: 0.4268
# Epoch 3/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 1.3314 - accuracy: 0.4612 - val_loss: 1.2149 - val_accuracy: 0.5108
# Epoch 4/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 1.2170 - accuracy: 0.4985 - val_loss: 1.1595 - val_accuracy: 0.5230
# Epoch 5/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 1.1289 - accuracy: 0.5317 - val_loss: 1.1579 - val_accuracy: 0.5179
# Epoch 6/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 1.0696 - accuracy: 0.5472 - val_loss: 1.0673 - val_accuracy: 0.5525
# Epoch 7/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 1.0087 - accuracy: 0.5734 - val_loss: 1.0382 - val_accuracy: 0.5706
# Epoch 8/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.9564 - accuracy: 0.5920 - val_loss: 1.0496 - val_accuracy: 0.5643
# Epoch 9/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.9114 - accuracy: 0.6078 - val_loss: 1.0371 - val_accuracy: 0.5879
# Epoch 10/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.8596 - accuracy: 0.6351 - val_loss: 1.0630 - val_accuracy: 0.5618
# Epoch 11/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.8040 - accuracy: 0.6583 - val_loss: 1.1331 - val_accuracy: 0.5749
# Epoch 12/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.7555 - accuracy: 0.6822 - val_loss: 1.2082 - val_accuracy: 0.5323
# Epoch 13/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.7105 - accuracy: 0.6979 - val_loss: 1.0817 - val_accuracy: 0.5799
# Epoch 14/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.6609 - accuracy: 0.7200 - val_loss: 1.2330 - val_accuracy: 0.5753
# Epoch 15/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.6128 - accuracy: 0.7423 - val_loss: 1.1957 - val_accuracy: 0.5778
# Epoch 16/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.5641 - accuracy: 0.7662 - val_loss: 1.3246 - val_accuracy: 0.5432
# Epoch 17/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.5269 - accuracy: 0.7817 - val_loss: 1.3902 - val_accuracy: 0.5500
# Epoch 18/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.4742 - accuracy: 0.8081 - val_loss: 1.3539 - val_accuracy: 0.5711
# Epoch 19/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.4271 - accuracy: 0.8299 - val_loss: 1.4964 - val_accuracy: 0.5512
# Epoch 20/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.3901 - accuracy: 0.8499 - val_loss: 1.5741 - val_accuracy: 0.5652
# Epoch 21/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.3537 - accuracy: 0.8622 - val_loss: 1.8810 - val_accuracy: 0.5415
# Epoch 22/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.3202 - accuracy: 0.8815 - val_loss: 1.6572 - val_accuracy: 0.5639
# Epoch 23/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.3013 - accuracy: 0.8880 - val_loss: 1.8180 - val_accuracy: 0.5108
# Epoch 24/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.2693 - accuracy: 0.9040 - val_loss: 1.7803 - val_accuracy: 0.5753
# Epoch 25/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.2294 - accuracy: 0.9170 - val_loss: 1.6879 - val_accuracy: 0.5614
# Epoch 26/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.2205 - accuracy: 0.9217 - val_loss: 1.7666 - val_accuracy: 0.5631
# Epoch 27/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.2004 - accuracy: 0.9291 - val_loss: 1.9015 - val_accuracy: 0.5698
# Epoch 28/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1767 - accuracy: 0.9400 - val_loss: 1.8284 - val_accuracy: 0.5825
# Epoch 29/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1523 - accuracy: 0.9498 - val_loss: 2.0409 - val_accuracy: 0.5593
# Epoch 30/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1511 - accuracy: 0.9490 - val_loss: 2.0360 - val_accuracy: 0.5706
# Epoch 31/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1466 - accuracy: 0.9495 - val_loss: 2.3942 - val_accuracy: 0.5778
# Epoch 32/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1483 - accuracy: 0.9522 - val_loss: 1.9573 - val_accuracy: 0.5677
# Epoch 33/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1043 - accuracy: 0.9649 - val_loss: 2.1801 - val_accuracy: 0.5833
# Epoch 34/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1070 - accuracy: 0.9645 - val_loss: 1.9721 - val_accuracy: 0.5715
# Epoch 35/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1051 - accuracy: 0.9661 - val_loss: 2.3566 - val_accuracy: 0.5681
# Epoch 36/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1000 - accuracy: 0.9664 - val_loss: 2.4265 - val_accuracy: 0.5719
# Epoch 37/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0949 - accuracy: 0.9697 - val_loss: 2.2409 - val_accuracy: 0.5782
# Epoch 38/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0922 - accuracy: 0.9689 - val_loss: 2.2983 - val_accuracy: 0.5753
# Epoch 39/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0851 - accuracy: 0.9718 - val_loss: 2.1767 - val_accuracy: 0.5795
# Epoch 40/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0905 - accuracy: 0.9687 - val_loss: 2.0525 - val_accuracy: 0.5723
# Epoch 41/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0746 - accuracy: 0.9731 - val_loss: 2.6020 - val_accuracy: 0.5706
# Epoch 42/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0737 - accuracy: 0.9752 - val_loss: 2.4636 - val_accuracy: 0.5698
# Epoch 43/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0610 - accuracy: 0.9791 - val_loss: 2.7790 - val_accuracy: 0.5698
# Epoch 44/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0639 - accuracy: 0.9775 - val_loss: 2.7990 - val_accuracy: 0.5791
# Epoch 45/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0621 - accuracy: 0.9776 - val_loss: 2.5047 - val_accuracy: 0.5626
# Epoch 46/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0667 - accuracy: 0.9764 - val_loss: 2.4226 - val_accuracy: 0.5820
# Epoch 47/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0687 - accuracy: 0.9758 - val_loss: 2.2508 - val_accuracy: 0.5732
# Epoch 48/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0633 - accuracy: 0.9771 - val_loss: 2.4326 - val_accuracy: 0.5711
# Epoch 49/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0571 - accuracy: 0.9790 - val_loss: 2.9976 - val_accuracy: 0.5698
# Epoch 50/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0473 - accuracy: 0.9823 - val_loss: 3.1512 - val_accuracy: 0.5685
# Epoch 51/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0540 - accuracy: 0.9817 - val_loss: 2.5428 - val_accuracy: 0.5808
# Epoch 52/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0511 - accuracy: 0.9804 - val_loss: 2.3841 - val_accuracy: 0.5871
# Epoch 53/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0519 - accuracy: 0.9818 - val_loss: 2.6736 - val_accuracy: 0.5685
# Epoch 54/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0512 - accuracy: 0.9814 - val_loss: 2.8483 - val_accuracy: 0.5744
# Epoch 55/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0541 - accuracy: 0.9792 - val_loss: 2.7776 - val_accuracy: 0.5757
# Epoch 56/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0552 - accuracy: 0.9800 - val_loss: 2.6277 - val_accuracy: 0.5698
# Epoch 57/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0559 - accuracy: 0.9796 - val_loss: 2.5163 - val_accuracy: 0.5597
# Epoch 58/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0475 - accuracy: 0.9823 - val_loss: 2.8317 - val_accuracy: 0.5715
# Epoch 59/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0437 - accuracy: 0.9841 - val_loss: 2.7010 - val_accuracy: 0.5622
# Epoch 60/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0335 - accuracy: 0.9866 - val_loss: 2.9586 - val_accuracy: 0.5841
# Epoch 61/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0326 - accuracy: 0.9874 - val_loss: 2.8505 - val_accuracy: 0.5744
# Epoch 62/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0261 - accuracy: 0.9891 - val_loss: 3.1473 - val_accuracy: 0.5782
# Epoch 63/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0355 - accuracy: 0.9857 - val_loss: 2.8760 - val_accuracy: 0.5740
# Epoch 64/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0355 - accuracy: 0.9867 - val_loss: 2.8666 - val_accuracy: 0.5635
# Epoch 65/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0404 - accuracy: 0.9847 - val_loss: 2.7115 - val_accuracy: 0.5668
# Epoch 66/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0451 - accuracy: 0.9835 - val_loss: 2.9060 - val_accuracy: 0.5715
# Epoch 67/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0393 - accuracy: 0.9844 - val_loss: 3.1077 - val_accuracy: 0.5816
# Epoch 68/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0340 - accuracy: 0.9861 - val_loss: 3.3804 - val_accuracy: 0.5766
# Epoch 69/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0380 - accuracy: 0.9863 - val_loss: 2.6019 - val_accuracy: 0.5795
# Epoch 70/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0278 - accuracy: 0.9888 - val_loss: 3.0368 - val_accuracy: 0.5525
# Epoch 71/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0261 - accuracy: 0.9890 - val_loss: 3.2712 - val_accuracy: 0.5846
# Epoch 72/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0234 - accuracy: 0.9899 - val_loss: 3.1250 - val_accuracy: 0.5930
# Epoch 73/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0294 - accuracy: 0.9887 - val_loss: 3.0341 - val_accuracy: 0.5774
# Epoch 74/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0388 - accuracy: 0.9859 - val_loss: 2.9041 - val_accuracy: 0.5770
# Epoch 75/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0356 - accuracy: 0.9863 - val_loss: 2.7152 - val_accuracy: 0.5837
# Epoch 76/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0274 - accuracy: 0.9887 - val_loss: 2.8416 - val_accuracy: 0.5749
# Epoch 77/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0248 - accuracy: 0.9900 - val_loss: 2.9700 - val_accuracy: 0.5567
# Epoch 78/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0250 - accuracy: 0.9899 - val_loss: 3.4117 - val_accuracy: 0.5766
# Epoch 79/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0251 - accuracy: 0.9900 - val_loss: 3.1176 - val_accuracy: 0.5782
# Epoch 80/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0165 - accuracy: 0.9921 - val_loss: 3.4603 - val_accuracy: 0.5770
# Epoch 81/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0159 - accuracy: 0.9928 - val_loss: 3.4623 - val_accuracy: 0.5753
# Epoch 82/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0192 - accuracy: 0.9913 - val_loss: 3.0922 - val_accuracy: 0.5766
# Epoch 83/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0315 - accuracy: 0.9871 - val_loss: 3.2922 - val_accuracy: 0.5896
# Epoch 84/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0269 - accuracy: 0.9895 - val_loss: 3.2582 - val_accuracy: 0.5698
# Epoch 85/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0199 - accuracy: 0.9909 - val_loss: 3.3282 - val_accuracy: 0.5744
# Epoch 86/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0181 - accuracy: 0.9911 - val_loss: 3.3713 - val_accuracy: 0.5829
# Epoch 87/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0197 - accuracy: 0.9912 - val_loss: 3.1464 - val_accuracy: 0.5795
# Epoch 88/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0194 - accuracy: 0.9914 - val_loss: 3.4025 - val_accuracy: 0.5799
# Epoch 89/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0240 - accuracy: 0.9906 - val_loss: 3.7664 - val_accuracy: 0.5867
# Epoch 90/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0232 - accuracy: 0.9902 - val_loss: 3.2374 - val_accuracy: 0.5719
# Epoch 91/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0218 - accuracy: 0.9907 - val_loss: 3.2113 - val_accuracy: 0.5702
# Epoch 92/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0232 - accuracy: 0.9900 - val_loss: 2.9976 - val_accuracy: 0.5740
# Epoch 93/100
# 18963/18963 [==============================] - 45s 2ms/step - loss: 0.0237 - accuracy: 0.9896 - val_loss: 3.3572 - val_accuracy: 0.5744
# Epoch 94/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0232 - accuracy: 0.9905 - val_loss: 3.8180 - val_accuracy: 0.5588
# Epoch 95/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0183 - accuracy: 0.9915 - val_loss: 3.3086 - val_accuracy: 0.5635
# Epoch 96/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0229 - accuracy: 0.9907 - val_loss: 3.0630 - val_accuracy: 0.5673
# Epoch 97/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0220 - accuracy: 0.9915 - val_loss: 3.1972 - val_accuracy: 0.5732
# Epoch 98/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0143 - accuracy: 0.9933 - val_loss: 3.4909 - val_accuracy: 0.5660
# Epoch 99/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0220 - accuracy: 0.9906 - val_loss: 3.2694 - val_accuracy: 0.5643
# Epoch 100/100
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0187 - accuracy: 0.9913 - val_loss: 3.5985 - val_accuracy: 0.5787

# %%
Y_test = np.argmax(y_test, axis=1)
y_pred = model.predict_classes(X_test)
target_names = ['1-7', '8-15', '16-25', '26-35', '36-45', '46-65', '66-116']
print(classification_report(Y_test, y_pred, target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#          1-7       0.91      0.88      0.90       241
#         8-15       0.59      0.57      0.58       121
#        16-25       0.50      0.34      0.41       367
#        26-35       0.55      0.71      0.62       735
#        36-45       0.32      0.23      0.26       305
#        46-65       0.55      0.61      0.58       429
#       66-116       0.68      0.51      0.59       173
#
#     accuracy                           0.57      2371
#    macro avg       0.59      0.55      0.56      2371
# weighted avg       0.56      0.57      0.56      2371

# %%
cm = confusion_matrix(y_test.argmax(axis=1), y_pred)
print(cm)
# Out:
# [[212  20   3   3   1   2   0]
#  [ 16  69  18  10   4   3   1]
#  [  1  17 126 205   9   8   1]
#  [  1   6  93 519  72  42   2]
#  [  1   1  11 133  69  88   2]
#  [  1   4   2  67  57 263  35]
#  [  0   0   0   4   5  75  89]]

# %%
fig,ax= plt.subplots(figsize=(7,7))
sns.heatmap(cm / (cm.astype(np.float).sum(axis=1, keepdims=True)), annot=True, fmt='.1%', cmap='Blues')
ax.set_xlabel('Predicted', size=20);
ax.set_ylabel('True', size=20);
ax.set_title('Confusion Matrix', size=20);
ax.xaxis.set_ticklabels(target_names, size=10); \
ax.yaxis.set_ticklabels(target_names, size=10);
