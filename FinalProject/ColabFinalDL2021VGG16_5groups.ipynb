# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.layers import LeakyReLU
from keras.optimizers import Adam
import cv2
import keras
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
age_data = pd.read_csv('gdrive/My Drive/age_gender.csv')

# %%
age_data.head(3)
# Out:
#    age  ...                                             pixels
# 0    1  ...  129 128 128 126 127 130 133 135 139 142 145 14...
# 1    1  ...  164 74 111 168 169 171 175 182 184 188 193 199...
# 2    1  ...  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
#
# [3 rows x 5 columns]

# %%
def label_age (row):
    if row['age'] > 0 and row['age'] < 8:
        return 0
    elif row['age'] > 7 and row['age'] < 20:
        return 1
    elif row['age'] > 19 and row['age'] < 40:
        return 2
    elif row['age'] > 39 and row['age'] < 60:
        return 3
    else:
        return 4

# %%
age_data['AgeGroup'] = age_data.apply (lambda row: label_age(row), axis=1)

# %%
age_data.head(3)
# Out:
#    age  ethnicity  ...                                             pixels AgeGroup
# 0    1          2  ...  129 128 128 126 127 130 133 135 139 142 145 14...        0
# 1    1          2  ...  164 74 111 168 169 171 175 182 184 188 193 199...        0
# 2    1          2  ...  67 70 71 70 69 67 70 79 90 103 116 132 145 155...        0
#
# [3 rows x 6 columns]

# %%
X = []
y = []
for index, row in age_data.iterrows():
    k = row['pixels'].split(" ")
    X.append(np.array(k))
    y.append(row['AgeGroup'])
        
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.9, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.8/0.9, random_state=42)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_valid = np.array(X_valid)
y_valid = np.array(y_valid)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train.reshape(X_train.shape[0], 48, 48, 1)
X_valid = X_valid.reshape(X_valid.shape[0], 48, 48, 1)
X_test = X_test.reshape(X_test.shape[0], 48, 48, 1)

y_train = np_utils.to_categorical(y_train, num_classes = 5)
y_valid = np_utils.to_categorical(y_valid, num_classes = 5)
y_test = np_utils.to_categorical(y_test, num_classes = 5)

# %%
X_train.shape
# Out:
# (18963, 48, 48, 1)

# %%
X_valid.shape
# Out:
# (2371, 48, 48, 1)

# %%
X_test.shape
# Out:
# (2371, 48, 48, 1)

# %%
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(48,48,1)))
model.add(Convolution2D(64, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(5, activation='softmax'))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer= 'sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train,y_train,batch_size=32,epochs=30,verbose=1,validation_data=(X_valid, y_valid))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 18963 samples, validate on 2371 samples
# Epoch 1/30
# 18963/18963 [==============================] - 51s 3ms/step - loss: 1.3083 - accuracy: 0.5110 - val_loss: 1.1658 - val_accuracy: 0.5841
# Epoch 2/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 1.0493 - accuracy: 0.5961 - val_loss: 1.1896 - val_accuracy: 0.5588
# Epoch 3/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.8791 - accuracy: 0.6549 - val_loss: 0.7874 - val_accuracy: 0.6904
# Epoch 4/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.7734 - accuracy: 0.6940 - val_loss: 0.7363 - val_accuracy: 0.7170
# Epoch 5/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.7114 - accuracy: 0.7166 - val_loss: 0.7774 - val_accuracy: 0.6824
# Epoch 6/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.6531 - accuracy: 0.7412 - val_loss: 0.7158 - val_accuracy: 0.7027
# Epoch 7/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.5989 - accuracy: 0.7587 - val_loss: 0.6209 - val_accuracy: 0.7600
# Epoch 8/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.5558 - accuracy: 0.7784 - val_loss: 0.6281 - val_accuracy: 0.7448
# Epoch 9/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.5106 - accuracy: 0.7957 - val_loss: 0.6404 - val_accuracy: 0.7613
# Epoch 10/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.4664 - accuracy: 0.8127 - val_loss: 0.6502 - val_accuracy: 0.7457
# Epoch 11/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.4247 - accuracy: 0.8304 - val_loss: 0.7220 - val_accuracy: 0.7499
# Epoch 12/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.3762 - accuracy: 0.8545 - val_loss: 0.6779 - val_accuracy: 0.7495
# Epoch 13/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.3361 - accuracy: 0.8676 - val_loss: 0.7426 - val_accuracy: 0.7533
# Epoch 14/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.2998 - accuracy: 0.8835 - val_loss: 0.8010 - val_accuracy: 0.7727
# Epoch 15/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.2682 - accuracy: 0.8974 - val_loss: 0.7337 - val_accuracy: 0.7491
# Epoch 16/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.2338 - accuracy: 0.9097 - val_loss: 1.1789 - val_accuracy: 0.6432
# Epoch 17/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.2118 - accuracy: 0.9210 - val_loss: 0.9202 - val_accuracy: 0.7301
# Epoch 18/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1815 - accuracy: 0.9358 - val_loss: 0.9731 - val_accuracy: 0.7415
# Epoch 19/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1571 - accuracy: 0.9452 - val_loss: 1.1941 - val_accuracy: 0.7533
# Epoch 20/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.1421 - accuracy: 0.9501 - val_loss: 1.2335 - val_accuracy: 0.7402
# Epoch 21/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.1324 - accuracy: 0.9553 - val_loss: 1.1036 - val_accuracy: 0.7377
# Epoch 22/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.1203 - accuracy: 0.9575 - val_loss: 1.1227 - val_accuracy: 0.7453
# Epoch 23/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.1064 - accuracy: 0.9654 - val_loss: 1.0237 - val_accuracy: 0.7469
# Epoch 24/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0809 - accuracy: 0.9751 - val_loss: 1.0973 - val_accuracy: 0.7554
# Epoch 25/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.0799 - accuracy: 0.9753 - val_loss: 1.2223 - val_accuracy: 0.7566
# Epoch 26/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0735 - accuracy: 0.9790 - val_loss: 1.3423 - val_accuracy: 0.7052
# Epoch 27/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.0581 - accuracy: 0.9850 - val_loss: 1.0700 - val_accuracy: 0.7545
# Epoch 28/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0481 - accuracy: 0.9874 - val_loss: 1.1482 - val_accuracy: 0.7444
# Epoch 29/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.0505 - accuracy: 0.9854 - val_loss: 1.4392 - val_accuracy: 0.7512
# Epoch 30/30
# 18963/18963 [==============================] - 44s 2ms/step - loss: 0.0458 - accuracy: 0.9872 - val_loss: 1.4777 - val_accuracy: 0.7558

# %%
Y_test = np.argmax(y_test, axis=1)
y_pred = model.predict_classes(X_test)
target_names = ['1-7', '8-19', '20-39', '40-59', '60-116']
print(classification_report(Y_test, y_pred, target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#          1-7       0.91      0.89      0.90       241
#         8-19       0.53      0.53      0.53       194
#        20-39       0.77      0.90      0.83      1159
#        40-59       0.65      0.47      0.54       504
#       60-116       0.76      0.63      0.69       273
#
#     accuracy                           0.75      2371
#    macro avg       0.73      0.68      0.70      2371
# weighted avg       0.74      0.75      0.74      2371

# %%
cm = confusion_matrix(y_test.argmax(axis=1), y_pred)
print(cm)
# Out:
# [[ 214   22    4    0    1]
#  [  19  103   71    1    0]
#  [   0   53 1043   55    8]
#  [   0   14  211  235   44]
#  [   1    2   29   69  172]]

# %%
fig,ax= plt.subplots(figsize=(5,5))
sns.heatmap(cm / (cm.astype(np.float).sum(axis=1, keepdims=True)), annot=True, fmt='.1%', cmap='Blues')
ax.set_xlabel('Predicted', size=20);
ax.set_ylabel('True', size=20);
ax.set_title('Confusion Matrix', size=20);
ax.xaxis.set_ticklabels(target_names, size=10); \
ax.yaxis.set_ticklabels(target_names, size=10);
