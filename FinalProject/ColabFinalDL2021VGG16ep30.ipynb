# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers.core import Flatten, Dense, Dropout
from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.layers import LeakyReLU
from keras.optimizers import Adam
import cv2
import keras
from keras.utils import np_utils
from keras.utils.np_utils import to_categorical
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
age_data = pd.read_csv('gdrive/My Drive/age_gender.csv')

# %%
age_data.head(3)
# Out:
#    age  ...                                             pixels
# 0    1  ...  129 128 128 126 127 130 133 135 139 142 145 14...
# 1    1  ...  164 74 111 168 169 171 175 182 184 188 193 199...
# 2    1  ...  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
#
# [3 rows x 5 columns]

# %%
def label_age (row):
    if row['age'] > 0 and row['age'] < 8:
        return 0
    elif row['age'] > 7 and row['age'] < 16:
        return 1
    elif row['age'] > 15 and row['age'] < 26:
        return 2
    elif row['age'] > 25 and row['age'] < 36:
        return 3
    elif row['age'] > 35 and row['age'] < 46:
        return 4
    elif row['age'] > 45 and row['age'] < 66:
        return 5
    else:
        return 6

# %%
age_data['AgeGroup'] = age_data.apply (lambda row: label_age(row), axis=1)

# %%
age_data.head(3)
# Out:
#    age  ethnicity  ...                                             pixels AgeGroup
# 0    1          2  ...  129 128 128 126 127 130 133 135 139 142 145 14...        0
# 1    1          2  ...  164 74 111 168 169 171 175 182 184 188 193 199...        0
# 2    1          2  ...  67 70 71 70 69 67 70 79 90 103 116 132 145 155...        0
#
# [3 rows x 6 columns]

# %%
X = []
y = []
for index, row in age_data.iterrows():
    k = row['pixels'].split(" ")
    X.append(np.array(k))
    y.append(row['AgeGroup'])
        
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.9, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, train_size=0.8/0.9, random_state=42)

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_valid = np.array(X_valid)
y_valid = np.array(y_valid)
X_test = np.array(X_test)
y_test = np.array(y_test)

X_train = X_train.reshape(X_train.shape[0], 48, 48, 1)
X_valid = X_valid.reshape(X_valid.shape[0], 48, 48, 1)
X_test = X_test.reshape(X_test.shape[0], 48, 48, 1)

y_train = np_utils.to_categorical(y_train, num_classes = 7)
y_valid = np_utils.to_categorical(y_valid, num_classes = 7)
y_test = np_utils.to_categorical(y_test, num_classes = 7)

# %%
X_train.shape
# Out:
# (18963, 48, 48, 1)

# %%
X_valid.shape
# Out:
# (2371, 48, 48, 1)

# %%
X_test.shape
# Out:
# (2371, 48, 48, 1)

# %%
model = Sequential()
model.add(ZeroPadding2D((1,1),input_shape=(48,48,1)))
model.add(Convolution2D(64, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(64, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(128, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(256, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(ZeroPadding2D((1,1)))
model.add(Convolution2D(512, (3, 3), activation="relu"))
model.add(MaxPooling2D((2,2), strides=(2,2)))

model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
model.compile(optimizer= 'sgd', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train,y_train,batch_size=32,epochs=30,verbose=1,validation_data=(X_valid, y_valid))
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 18963 samples, validate on 2371 samples
# Epoch 1/30
# 18963/18963 [==============================] - 51s 3ms/step - loss: 1.7962 - accuracy: 0.3143 - val_loss: 1.6944 - val_accuracy: 0.3281
# Epoch 2/30
# 18963/18963 [==============================] - 42s 2ms/step - loss: 1.5697 - accuracy: 0.3874 - val_loss: 1.3358 - val_accuracy: 0.4724
# Epoch 3/30
# 18963/18963 [==============================] - 42s 2ms/step - loss: 1.3290 - accuracy: 0.4685 - val_loss: 1.1874 - val_accuracy: 0.5167
# Epoch 4/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 1.2083 - accuracy: 0.5010 - val_loss: 1.3626 - val_accuracy: 0.4597
# Epoch 5/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 1.1203 - accuracy: 0.5302 - val_loss: 1.0881 - val_accuracy: 0.5445
# Epoch 6/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 1.0536 - accuracy: 0.5566 - val_loss: 1.0498 - val_accuracy: 0.5694
# Epoch 7/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 1.0018 - accuracy: 0.5757 - val_loss: 1.0307 - val_accuracy: 0.5702
# Epoch 8/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.9435 - accuracy: 0.5994 - val_loss: 1.0405 - val_accuracy: 0.5711
# Epoch 9/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.8941 - accuracy: 0.6204 - val_loss: 1.1349 - val_accuracy: 0.5293
# Epoch 10/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.8448 - accuracy: 0.6414 - val_loss: 1.0798 - val_accuracy: 0.5668
# Epoch 11/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.7970 - accuracy: 0.6577 - val_loss: 1.0355 - val_accuracy: 0.5723
# Epoch 12/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.7407 - accuracy: 0.6858 - val_loss: 1.0646 - val_accuracy: 0.5791
# Epoch 13/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.6904 - accuracy: 0.7093 - val_loss: 1.1521 - val_accuracy: 0.5496
# Epoch 14/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.6443 - accuracy: 0.7301 - val_loss: 1.2042 - val_accuracy: 0.5563
# Epoch 15/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.5966 - accuracy: 0.7514 - val_loss: 1.3405 - val_accuracy: 0.5428
# Epoch 16/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.5509 - accuracy: 0.7721 - val_loss: 1.5110 - val_accuracy: 0.5584
# Epoch 17/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.5014 - accuracy: 0.7983 - val_loss: 1.5117 - val_accuracy: 0.5576
# Epoch 18/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.4617 - accuracy: 0.8136 - val_loss: 1.4625 - val_accuracy: 0.5407
# Epoch 19/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.4146 - accuracy: 0.8371 - val_loss: 1.5080 - val_accuracy: 0.5453
# Epoch 20/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.3739 - accuracy: 0.8549 - val_loss: 1.4120 - val_accuracy: 0.5702
# Epoch 21/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.3526 - accuracy: 0.8662 - val_loss: 1.5537 - val_accuracy: 0.5681
# Epoch 22/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.3078 - accuracy: 0.8847 - val_loss: 1.6760 - val_accuracy: 0.5728
# Epoch 23/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.2878 - accuracy: 0.8927 - val_loss: 1.8022 - val_accuracy: 0.5550
# Epoch 24/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.2475 - accuracy: 0.9124 - val_loss: 1.8613 - val_accuracy: 0.5538
# Epoch 25/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.2278 - accuracy: 0.9213 - val_loss: 1.8172 - val_accuracy: 0.5550
# Epoch 26/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.2098 - accuracy: 0.9265 - val_loss: 1.8759 - val_accuracy: 0.5736
# Epoch 27/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.1910 - accuracy: 0.9355 - val_loss: 1.9302 - val_accuracy: 0.5837
# Epoch 28/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.1700 - accuracy: 0.9427 - val_loss: 1.8535 - val_accuracy: 0.5614
# Epoch 29/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.1556 - accuracy: 0.9504 - val_loss: 2.0959 - val_accuracy: 0.5702
# Epoch 30/30
# 18963/18963 [==============================] - 43s 2ms/step - loss: 0.1487 - accuracy: 0.9502 - val_loss: 1.9924 - val_accuracy: 0.5757

# %%
Y_test = np.argmax(y_test, axis=1)
y_pred = model.predict_classes(X_test)
target_names = ['1-7', '8-15', '16-25', '26-35', '36-45', '46-65', '66-116']
print(classification_report(Y_test, y_pred, target_names = target_names))
# Out:
#               precision    recall  f1-score   support
#
#          1-7       0.93      0.91      0.92       241
#         8-15       0.64      0.48      0.55       121
#        16-25       0.47      0.50      0.49       367
#        26-35       0.56      0.53      0.55       735
#        36-45       0.32      0.41      0.36       305
#        46-65       0.55      0.60      0.58       429
#       66-116       0.75      0.47      0.58       173
#
#     accuracy                           0.55      2371
#    macro avg       0.60      0.56      0.57      2371
# weighted avg       0.57      0.55      0.56      2371

# %%
cm = confusion_matrix(y_test.argmax(axis=1), y_pred)
print(cm)
# Out:
# [[219  12   7   1   0   2   0]
#  [ 13  58  28  10   6   4   2]
#  [  0  11 185 148  18   5   0]
#  [  1   5 160 388 138  42   1]
#  [  1   1  11  88 124  77   3]
#  [  1   2   3  50  93 259  21]
#  [  0   2   0   3   8  79  81]]

# %%
fig,ax= plt.subplots(figsize=(7,7))
sns.heatmap(cm / (cm.astype(np.float).sum(axis=1, keepdims=True)), annot=True, fmt='.1%', cmap='Blues')
ax.set_xlabel('Predicted', size=20);
ax.set_ylabel('True', size=20);
ax.set_title('Confusion Matrix', size=20);
ax.xaxis.set_ticklabels(target_names, size=10); \
ax.yaxis.set_ticklabels(target_names, size=10);
